# %%
# Import packages

import cv2
import os
import numpy as np
import random
from PIL import Image
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

#Tensorflow
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras import Sequential
from tensorflow.keras.layers import (Dense, Dropout, Input,Conv2D, Flatten,
                             MaxPooling2D,BatchNormalization)
from tensorflow.keras.utils import to_categorical
from keras.callbacks import EarlyStopping



#Torch
import torch
import torch.nn as nn
from torchvision import transforms
import torch.optim as optim
from torch.optim import lr_scheduler

#Scikit_learn
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import (roc_curve, accuracy_score, ConfusionMatrixDisplay, confusion_matrix)
from sklearn import metrics
from sklearn.model_selection import StratifiedKFold

# %%
# If using Google Colab.

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Check GPU information

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Thu May 30 07:09:24 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA L4                      Off | 00000000:00:03.0 Off |                    0 |
# | N/A   40C    P8              11W /  72W |      1MiB / 23034MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# Check the available RAM

from psutil import virtual_memory

ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 67.4 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
tf.random.set_seed(0)
random.seed(0)

# %%
def load_galaxy_images(data_dir, categories, target_size):
        
        """
        Loads, resizes, and processes all JPG images from the specified directory.

        Parameters:
        data_dir (str): The directory containing the JPG images to be processed.
        target_size (tuple): The target size for resizing the images, specified as (width, height).

        Returns:
        list: A list of PIL Image objects, each representing a resized and processed image.

        The function performs the following steps:
        1. Lists all JPG image files in the specified directory.
        2. Reads each image using OpenCV.
        3. Resizes each image to the specified target size.
        4. Scales the pixel values and converts the image to a format compatible with PIL.
        5. Converts each resized image to a PIL Image object.
        6. Appends each PIL Image object to a list.
        7. Returns the list of PIL Image objects.
        """

        all_images = []

        file_path = [os.path.join(data_dir, filename) for filename in os.listdir(data_dir) if filename.endswith('.jpg')]

        for img in file_path:
            image = cv2.imread(img)
            resized_images=cv2.resize(image, target_size)
            resized_images = (resized_images * 255).astype(np.uint8)
            pil_images = Image.fromarray(resized_images)
            all_images.append(pil_images)

        return all_images

# %%
g_im = '/path/to/your/direcotry/galaxy'
ng_im = '/path/to/your/direcotry/non_galaxy'

categories = ['g', 'ng']

g_img = load_galaxy_images(g_im, categories=categories[0], target_size=(200,200))
ng_img = load_galaxy_images(ng_im, categories=categories[1], target_size=(200,200))

all_data = g_img + ng_img
np.shape(all_data)
# Out:
# (1325, 200, 200, 3)

# %%
input_size = 200

# transforms for training data
train_transform = transforms.Compose([transforms.CenterCrop(input_size),
                                      transforms.RandomRotation(90),
                                      transforms.RandomHorizontalFlip(),
                                      transforms.RandomVerticalFlip(),
                                      transforms.RandomResizedCrop(input_size, scale=(0.8, 1.0), ratio=(0.99, 1.01)),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
                                      ])


# transforms for test data
test_transform = transforms.Compose([transforms.CenterCrop(input_size),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
                                      ])

# %%
# Labels

galaxies_labels = np.zeros(len(g_img))
nongalaxy_labels = np.ones(len(ng_img))

all_labels = np.concatenate([galaxies_labels, nongalaxy_labels])
len(all_labels)
# Out:
# 1325

# %% [markdown]
# ### Classic CNN

# %%
y_test_list=[]
models=[]
Y_pred=[]
accs=[]
cons=[]
test_indx=[]

b_size = 64
e_num = 30

for i in range (10):
    X_train, X_test, y_train, y_test, train_indices, test_indices = train_test_split(all_data, all_labels, np.arange(len(all_labels)), test_size=0.25, shuffle=True, random_state=None)
    y_test_list.append(y_test)
    test_indx.append(test_indices)

    y_train_encoded = to_categorical(y_train, num_classes=2)
    class_weights = {0: len(all_data) / (2*len(g_img)), 1: len(all_data) / (2*len(ng_img))}

    # Transformer for training data
    transformed_X_train=[]
    for i in range(len(X_train)):
      transformed_train_images = train_transform(X_train[i])
      new_image = np.transpose(transformed_train_images, (1, 2, 0))
      transformed_X_train.append(new_image)

    # Transformer for testing data
    transformed_X_test=[]
    for j in range(len(X_test)):
      transformed_test_images = test_transform(X_test[j])
      new_images = np.transpose(transformed_test_images, (1, 2, 0))
      transformed_X_test.append(new_images)

    # input
    x = Input(shape=(200,200,3))

    #hidden layers
    c0 = Conv2D(256, kernel_size=(3,3), strides=(1,1), padding="same")(x)
    b0 = BatchNormalization()(c0)
    m0 = MaxPooling2D(pool_size=(2, 2))(b0)
    d0 = Dropout(0.1)(m0)

    c1 = Conv2D(128, kernel_size=(3,3), strides=(1,1), padding="same")(m0)
    b1 = BatchNormalization()(c1)
    m1 = MaxPooling2D(pool_size=(2, 2))(b1)
    d1 = Dropout(0.1)(m1)

    c2 = Conv2D(64, kernel_size=(3,3), strides=(1,1), padding="same")(m1)
    b2 = BatchNormalization()(c2)
    m2 = MaxPooling2D(pool_size=(2, 2))(b2)
    d2 = Dropout(0.1)(m2)

    f = Flatten()(m2)

    # output layers
    de0 = Dense(64, activation='relu')(f)
    de1 = Dense(32, activation='relu')(de0)
    de2 = Dense(2, activation='softmax')(de1)

    model = Model(inputs=x, outputs=de2, name="cnn_transformer_galaxy_nonegalaxy")
    loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)
    optimizer = tf.keras.optimizers.Adam()
    model.compile(loss=loss, optimizer=optimizer, metrics=['accuracy'])

    # Callback Functions
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

    history = model.fit(
    np.array(transformed_X_train), y_train_encoded,
    batch_size=b_size,
    epochs=e_num,
    verbose = 1,
    class_weight=class_weights,
    callbacks=es,
    validation_split=0.1
    )
    models.append(history)

    y_pred = model.predict(np.array(transformed_X_test))
    y_pred_labels = np.argmax(y_pred, axis=1)
    Y_pred.append(y_pred_labels)

    con0 = metrics.confusion_matrix(y_test, y_pred_labels)
    cons.append(con0)

    acc = metrics.accuracy_score(y_test, y_pred_labels)
    accs.append(acc)
# Out:
# Epoch 1/30
# 14/14 [==============================] - 41s 2s/step - loss: 1.9105 - accuracy: 0.5823 - val_loss: 8.3102 - val_accuracy: 0.5300
# Epoch 2/30
# 14/14 [==============================] - 5s 328ms/step - loss: 0.8343 - accuracy: 0.7010 - val_loss: 4.4952 - val_accuracy: 0.6900
# Epoch 3/30
# 14/14 [==============================] - 5s 329ms/step - loss: 0.7706 - accuracy: 0.6865 - val_loss: 5.3902 - val_accuracy: 0.5400
# Epoch 4/30
# 14/14 [==============================] - 5s 329ms/step - loss: 0.6933 - accuracy: 0.7469 - val_loss: 1.1269 - val_accuracy: 0.6900
# Epoch 5/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.5675 - accuracy: 0.7514 - val_loss: 2.4107 - val_accuracy: 0.5500
# Epoch 6/30
# 14/14 [==============================] - 5s 329ms/step - loss: 0.3874 - accuracy: 0.8298 - val_loss: 0.7252 - val_accuracy: 0.6900
# Epoch 7/30
# 14/14 [==============================] - 5s 329ms/step - loss: 0.3287 - accuracy: 0.8600 - val_loss: 0.6884 - val_accuracy: 0.6900
# Epoch 8/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.2396 - accuracy: 0.9037 - val_loss: 0.7424 - val_accuracy: 0.7300
# Epoch 9/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.2159 - accuracy: 0.9149 - val_loss: 0.5299 - val_accuracy: 0.7600
# Epoch 10/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.1963 - accuracy: 0.9328 - val_loss: 0.4833 - val_accuracy: 0.8300
# Epoch 11/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.1804 - accuracy: 0.9339 - val_loss: 0.5387 - val_accuracy: 0.8100
# Epoch 12/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.1832 - accuracy: 0.9227 - val_loss: 0.4526 - val_accuracy: 0.8300
# Epoch 13/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.1421 - accuracy: 0.9518 - val_loss: 0.4035 - val_accuracy: 0.8400
# Epoch 14/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.1263 - accuracy: 0.9552 - val_loss: 0.3854 - val_accuracy: 0.8600
# Epoch 15/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.1429 - accuracy: 0.9474 - val_loss: 0.6383 - val_accuracy: 0.7200
# Epoch 16/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.1542 - accuracy: 0.9362 - val_loss: 0.4781 - val_accuracy: 0.7900
# Epoch 17/30
# 14/14 [==============================] - 5s 333ms/step - loss: 0.1071 - accuracy: 0.9664 - val_loss: 0.4187 - val_accuracy: 0.8400
# Epoch 18/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.0725 - accuracy: 0.9821 - val_loss: 0.4515 - val_accuracy: 0.8600
# Epoch 19/30
# 14/14 [==============================] - 5s 333ms/step - loss: 0.0494 - accuracy: 0.9933 - val_loss: 0.4901 - val_accuracy: 0.8000
# Epoch 20/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.0554 - accuracy: 0.9944 - val_loss: 0.4272 - val_accuracy: 0.8400
# Epoch 21/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.0573 - accuracy: 0.9899 - val_loss: 0.4925 - val_accuracy: 0.8100
# Epoch 22/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.0589 - accuracy: 0.9810 - val_loss: 0.4438 - val_accuracy: 0.8300
# Epoch 23/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.0420 - accuracy: 0.9888 - val_loss: 0.4921 - val_accuracy: 0.8200
# Epoch 24/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.0290 - accuracy: 0.9966 - val_loss: 0.5550 - val_accuracy: 0.8600
# Epoch 24: early stopping
# 11/11 [==============================] - 5s 170ms/step
# Epoch 1/30
# 14/14 [==============================] - 7s 375ms/step - loss: 2.4687 - accuracy: 0.5980 - val_loss: 27.4325 - val_accuracy: 0.4400
# Epoch 2/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.8258 - accuracy: 0.6954 - val_loss: 1.8925 - val_accuracy: 0.6000
# Epoch 3/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.6371 - accuracy: 0.7570 - val_loss: 0.9901 - val_accuracy: 0.6900
# Epoch 4/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.5511 - accuracy: 0.7727 - val_loss: 0.8281 - val_accuracy: 0.7000
# Epoch 5/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.4555 - accuracy: 0.7962 - val_loss: 0.6587 - val_accuracy: 0.7300
# Epoch 6/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.3815 - accuracy: 0.8455 - val_loss: 1.4004 - val_accuracy: 0.6600
# Epoch 7/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.3946 - accuracy: 0.8186 - val_loss: 0.6219 - val_accuracy: 0.7800
# Epoch 8/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.3932 - accuracy: 0.8253 - val_loss: 1.4628 - val_accuracy: 0.4500
# Epoch 9/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.3531 - accuracy: 0.8466 - val_loss: 0.6569 - val_accuracy: 0.7000
# Epoch 10/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.3260 - accuracy: 0.8600 - val_loss: 0.6463 - val_accuracy: 0.6800
# Epoch 11/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.2925 - accuracy: 0.8768 - val_loss: 0.7088 - val_accuracy: 0.6700
# Epoch 12/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.2532 - accuracy: 0.8858 - val_loss: 0.7239 - val_accuracy: 0.6200
# Epoch 13/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.2699 - accuracy: 0.8802 - val_loss: 0.8238 - val_accuracy: 0.6700
# Epoch 14/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.2289 - accuracy: 0.9059 - val_loss: 0.8646 - val_accuracy: 0.6800
# Epoch 15/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.2260 - accuracy: 0.9082 - val_loss: 1.1448 - val_accuracy: 0.5800
# Epoch 16/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.2613 - accuracy: 0.9003 - val_loss: 1.0536 - val_accuracy: 0.6800
# Epoch 17/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.2590 - accuracy: 0.8981 - val_loss: 1.1892 - val_accuracy: 0.5600
# Epoch 17: early stopping
# 11/11 [==============================] - 1s 53ms/step
# Epoch 1/30
# 14/14 [==============================] - 7s 352ms/step - loss: 2.4622 - accuracy: 0.5666 - val_loss: 56.7769 - val_accuracy: 0.4400
# Epoch 2/30
# 14/14 [==============================] - 5s 334ms/step - loss: 0.8074 - accuracy: 0.6943 - val_loss: 1.9542 - val_accuracy: 0.5000
# Epoch 3/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.6408 - accuracy: 0.7133 - val_loss: 3.0190 - val_accuracy: 0.5300
# Epoch 4/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.6608 - accuracy: 0.7324 - val_loss: 1.6210 - val_accuracy: 0.5000
# Epoch 5/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.5097 - accuracy: 0.7816 - val_loss: 1.6659 - val_accuracy: 0.6500
# Epoch 6/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.5401 - accuracy: 0.7816 - val_loss: 0.7707 - val_accuracy: 0.6900
# Epoch 7/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.4122 - accuracy: 0.8085 - val_loss: 0.6434 - val_accuracy: 0.6400
# Epoch 8/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.3487 - accuracy: 0.8511 - val_loss: 1.0847 - val_accuracy: 0.5600
# Epoch 9/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.2528 - accuracy: 0.8992 - val_loss: 0.7678 - val_accuracy: 0.6200
# Epoch 10/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.2506 - accuracy: 0.8992 - val_loss: 0.6553 - val_accuracy: 0.6600
# Epoch 11/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.3227 - accuracy: 0.8578 - val_loss: 1.4179 - val_accuracy: 0.4300
# Epoch 12/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.2935 - accuracy: 0.8723 - val_loss: 1.3186 - val_accuracy: 0.4700
# Epoch 13/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.1868 - accuracy: 0.9183 - val_loss: 0.8912 - val_accuracy: 0.6100
# Epoch 14/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.1611 - accuracy: 0.9440 - val_loss: 0.5662 - val_accuracy: 0.7200
# Epoch 15/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.1237 - accuracy: 0.9630 - val_loss: 0.8634 - val_accuracy: 0.6200
# Epoch 16/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.1162 - accuracy: 0.9686 - val_loss: 1.1720 - val_accuracy: 0.5200
# Epoch 17/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.1149 - accuracy: 0.9586 - val_loss: 0.6171 - val_accuracy: 0.7200
# Epoch 18/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.0957 - accuracy: 0.9642 - val_loss: 0.8989 - val_accuracy: 0.6600
# Epoch 19/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.1095 - accuracy: 0.9563 - val_loss: 1.4822 - val_accuracy: 0.5400
# Epoch 20/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.1131 - accuracy: 0.9563 - val_loss: 1.1995 - val_accuracy: 0.6300
# Epoch 21/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.0731 - accuracy: 0.9754 - val_loss: 0.7787 - val_accuracy: 0.7100
# Epoch 22/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.0985 - accuracy: 0.9619 - val_loss: 0.6461 - val_accuracy: 0.7800
# Epoch 23/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.0600 - accuracy: 0.9821 - val_loss: 1.1286 - val_accuracy: 0.6700
# Epoch 24/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.0375 - accuracy: 0.9910 - val_loss: 0.7281 - val_accuracy: 0.7700
# Epoch 24: early stopping
# 11/11 [==============================] - 1s 53ms/step
# Epoch 1/30
# 14/14 [==============================] - 7s 354ms/step - loss: 1.7214 - accuracy: 0.6540 - val_loss: 5.3272 - val_accuracy: 0.4400
# Epoch 2/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.6115 - accuracy: 0.7256 - val_loss: 7.0694 - val_accuracy: 0.6000
# Epoch 3/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.5691 - accuracy: 0.7693 - val_loss: 1.1809 - val_accuracy: 0.5800
# Epoch 4/30
# 14/14 [==============================] - 5s 333ms/step - loss: 0.4166 - accuracy: 0.8298 - val_loss: 2.5145 - val_accuracy: 0.4300
# Epoch 5/30
# 14/14 [==============================] - 5s 333ms/step - loss: 0.4384 - accuracy: 0.7839 - val_loss: 0.9653 - val_accuracy: 0.6900
# Epoch 6/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.4354 - accuracy: 0.7973 - val_loss: 0.8164 - val_accuracy: 0.6900
# Epoch 7/30
# 14/14 [==============================] - 5s 333ms/step - loss: 0.3718 - accuracy: 0.8365 - val_loss: 0.7056 - val_accuracy: 0.6800
# Epoch 8/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.3110 - accuracy: 0.8555 - val_loss: 0.6767 - val_accuracy: 0.7200
# Epoch 9/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.2420 - accuracy: 0.9026 - val_loss: 0.7101 - val_accuracy: 0.7200
# Epoch 10/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.2056 - accuracy: 0.9216 - val_loss: 0.6076 - val_accuracy: 0.7300
# Epoch 11/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.1924 - accuracy: 0.9183 - val_loss: 0.6179 - val_accuracy: 0.7000
# Epoch 12/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.1779 - accuracy: 0.9373 - val_loss: 0.6069 - val_accuracy: 0.7400
# Epoch 13/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.1409 - accuracy: 0.9507 - val_loss: 0.5891 - val_accuracy: 0.7400
# Epoch 14/30
# 14/14 [==============================] - 5s 333ms/step - loss: 0.1838 - accuracy: 0.9261 - val_loss: 1.0553 - val_accuracy: 0.5100
# Epoch 15/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.1803 - accuracy: 0.9183 - val_loss: 0.7370 - val_accuracy: 0.7600
# Epoch 16/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.1111 - accuracy: 0.9619 - val_loss: 0.8336 - val_accuracy: 0.6300
# Epoch 17/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.0662 - accuracy: 0.9843 - val_loss: 0.7339 - val_accuracy: 0.7400
# Epoch 18/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.0469 - accuracy: 0.9944 - val_loss: 0.7757 - val_accuracy: 0.6900
# Epoch 19/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.0445 - accuracy: 0.9955 - val_loss: 0.8418 - val_accuracy: 0.7100
# Epoch 20/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.0369 - accuracy: 0.9955 - val_loss: 0.7722 - val_accuracy: 0.7300
# Epoch 21/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.0239 - accuracy: 0.9989 - val_loss: 0.9480 - val_accuracy: 0.6600
# Epoch 22/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.0223 - accuracy: 0.9989 - val_loss: 1.1167 - val_accuracy: 0.6000
# Epoch 23/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.0299 - accuracy: 0.9978 - val_loss: 0.9525 - val_accuracy: 0.7300
# Epoch 23: early stopping
# 11/11 [==============================] - 1s 53ms/step
# Epoch 1/30
# 14/14 [==============================] - 7s 353ms/step - loss: 3.5898 - accuracy: 0.6551 - val_loss: 11.9853 - val_accuracy: 0.4800
# Epoch 2/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.7745 - accuracy: 0.7234 - val_loss: 2.3288 - val_accuracy: 0.6600
# Epoch 3/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.7381 - accuracy: 0.7458 - val_loss: 2.9870 - val_accuracy: 0.6300
# Epoch 4/30
# 14/14 [==============================] - 5s 333ms/step - loss: 0.5187 - accuracy: 0.8063 - val_loss: 2.6843 - val_accuracy: 0.6500
# Epoch 5/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.4645 - accuracy: 0.8231 - val_loss: 2.3847 - val_accuracy: 0.4900
# Epoch 6/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.3231 - accuracy: 0.8600 - val_loss: 0.9942 - val_accuracy: 0.6100
# Epoch 7/30
# 14/14 [==============================] - 5s 333ms/step - loss: 0.2447 - accuracy: 0.9048 - val_loss: 0.7643 - val_accuracy: 0.6800
# Epoch 8/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.2229 - accuracy: 0.9015 - val_loss: 0.7746 - val_accuracy: 0.6400
# Epoch 9/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.1964 - accuracy: 0.9306 - val_loss: 1.2413 - val_accuracy: 0.5900
# Epoch 10/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.1552 - accuracy: 0.9373 - val_loss: 0.9330 - val_accuracy: 0.6400
# Epoch 11/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.1362 - accuracy: 0.9418 - val_loss: 0.7657 - val_accuracy: 0.7100
# Epoch 12/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.3007 - accuracy: 0.8880 - val_loss: 0.8097 - val_accuracy: 0.6900
# Epoch 13/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.2511 - accuracy: 0.9003 - val_loss: 0.5415 - val_accuracy: 0.7900
# Epoch 14/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.1837 - accuracy: 0.9160 - val_loss: 0.6388 - val_accuracy: 0.7600
# Epoch 15/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.1145 - accuracy: 0.9574 - val_loss: 0.8663 - val_accuracy: 0.6200
# Epoch 16/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.0576 - accuracy: 0.9854 - val_loss: 0.8573 - val_accuracy: 0.6700
# Epoch 17/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.0390 - accuracy: 0.9877 - val_loss: 1.6050 - val_accuracy: 0.5200
# Epoch 18/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.0662 - accuracy: 0.9888 - val_loss: 1.0446 - val_accuracy: 0.6500
# Epoch 19/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.0274 - accuracy: 0.9910 - val_loss: 0.8831 - val_accuracy: 0.7500
# Epoch 20/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.0260 - accuracy: 0.9933 - val_loss: 0.6613 - val_accuracy: 0.7800
# Epoch 21/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.0150 - accuracy: 0.9978 - val_loss: 0.8127 - val_accuracy: 0.7100
# Epoch 22/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.8483 - val_accuracy: 0.7300
# Epoch 23/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.6845 - val_accuracy: 0.7600
# Epoch 23: early stopping
# 11/11 [==============================] - 1s 53ms/step
# Epoch 1/30
# 14/14 [==============================] - 7s 352ms/step - loss: 2.3004 - accuracy: 0.6170 - val_loss: 17.0223 - val_accuracy: 0.3500
# Epoch 2/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.7830 - accuracy: 0.7346 - val_loss: 4.1353 - val_accuracy: 0.4600
# Epoch 3/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.7805 - accuracy: 0.7458 - val_loss: 9.5901 - val_accuracy: 0.3300
# Epoch 4/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.6486 - accuracy: 0.7469 - val_loss: 1.6645 - val_accuracy: 0.4200
# Epoch 5/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.4516 - accuracy: 0.8331 - val_loss: 0.9956 - val_accuracy: 0.5700
# Epoch 6/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.5419 - accuracy: 0.7895 - val_loss: 0.7655 - val_accuracy: 0.6700
# Epoch 7/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.4771 - accuracy: 0.8029 - val_loss: 0.6654 - val_accuracy: 0.6800
# Epoch 8/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.3248 - accuracy: 0.8712 - val_loss: 0.9156 - val_accuracy: 0.5400
# Epoch 9/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.2902 - accuracy: 0.8891 - val_loss: 0.8088 - val_accuracy: 0.5800
# Epoch 10/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.2832 - accuracy: 0.8847 - val_loss: 0.7351 - val_accuracy: 0.6200
# Epoch 11/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.2271 - accuracy: 0.9127 - val_loss: 1.0439 - val_accuracy: 0.5000
# Epoch 12/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.2047 - accuracy: 0.9250 - val_loss: 1.6903 - val_accuracy: 0.3800
# Epoch 13/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.1630 - accuracy: 0.9440 - val_loss: 1.5272 - val_accuracy: 0.4000
# Epoch 14/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.1473 - accuracy: 0.9586 - val_loss: 1.6807 - val_accuracy: 0.3900
# Epoch 15/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.1207 - accuracy: 0.9742 - val_loss: 1.6796 - val_accuracy: 0.4300
# Epoch 16/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.0941 - accuracy: 0.9798 - val_loss: 1.6817 - val_accuracy: 0.4500
# Epoch 17/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.1034 - accuracy: 0.9608 - val_loss: 0.8846 - val_accuracy: 0.6100
# Epoch 17: early stopping
# 11/11 [==============================] - 1s 52ms/step
# Epoch 1/30
# 14/14 [==============================] - 7s 351ms/step - loss: 2.9468 - accuracy: 0.6058 - val_loss: 28.5720 - val_accuracy: 0.4000
# Epoch 2/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.7181 - accuracy: 0.7391 - val_loss: 4.8758 - val_accuracy: 0.6300
# Epoch 3/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.5859 - accuracy: 0.7536 - val_loss: 1.9604 - val_accuracy: 0.6500
# Epoch 4/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.4064 - accuracy: 0.8219 - val_loss: 1.5451 - val_accuracy: 0.4900
# Epoch 5/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.3435 - accuracy: 0.8634 - val_loss: 0.8421 - val_accuracy: 0.5800
# Epoch 6/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.3179 - accuracy: 0.8791 - val_loss: 0.9100 - val_accuracy: 0.5600
# Epoch 7/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.3083 - accuracy: 0.8936 - val_loss: 0.7499 - val_accuracy: 0.5900
# Epoch 8/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.2856 - accuracy: 0.8903 - val_loss: 0.6658 - val_accuracy: 0.5700
# Epoch 9/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.2382 - accuracy: 0.9059 - val_loss: 0.9123 - val_accuracy: 0.5800
# Epoch 10/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.1964 - accuracy: 0.9283 - val_loss: 1.4711 - val_accuracy: 0.5200
# Epoch 11/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.1609 - accuracy: 0.9429 - val_loss: 1.2599 - val_accuracy: 0.5200
# Epoch 12/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.2126 - accuracy: 0.9071 - val_loss: 0.6572 - val_accuracy: 0.6500
# Epoch 13/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.1532 - accuracy: 0.9440 - val_loss: 0.7379 - val_accuracy: 0.6100
# Epoch 14/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.1321 - accuracy: 0.9429 - val_loss: 0.9151 - val_accuracy: 0.5700
# Epoch 15/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.1029 - accuracy: 0.9642 - val_loss: 0.8361 - val_accuracy: 0.6000
# Epoch 16/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.1375 - accuracy: 0.9440 - val_loss: 0.7245 - val_accuracy: 0.6900
# Epoch 17/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.0752 - accuracy: 0.9787 - val_loss: 1.1073 - val_accuracy: 0.6000
# Epoch 18/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.0954 - accuracy: 0.9619 - val_loss: 1.2255 - val_accuracy: 0.6300
# Epoch 19/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.1578 - accuracy: 0.9306 - val_loss: 1.1191 - val_accuracy: 0.6400
# Epoch 20/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.1243 - accuracy: 0.9496 - val_loss: 1.3241 - val_accuracy: 0.6100
# Epoch 21/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.0715 - accuracy: 0.9798 - val_loss: 1.0237 - val_accuracy: 0.6500
# Epoch 22/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.0346 - accuracy: 0.9944 - val_loss: 0.9585 - val_accuracy: 0.7200
# Epoch 22: early stopping
# 11/11 [==============================] - 1s 53ms/step
# Epoch 1/30
# 14/14 [==============================] - 7s 348ms/step - loss: 2.4222 - accuracy: 0.6249 - val_loss: 9.9061 - val_accuracy: 0.4100
# Epoch 2/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.5927 - accuracy: 0.7212 - val_loss: 2.7668 - val_accuracy: 0.6000
# Epoch 3/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.4973 - accuracy: 0.7525 - val_loss: 1.6713 - val_accuracy: 0.6200
# Epoch 4/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.4404 - accuracy: 0.8141 - val_loss: 1.1546 - val_accuracy: 0.6500
# Epoch 5/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.4060 - accuracy: 0.8231 - val_loss: 0.6634 - val_accuracy: 0.7200
# Epoch 6/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.3998 - accuracy: 0.8275 - val_loss: 1.2715 - val_accuracy: 0.4400
# Epoch 7/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.4054 - accuracy: 0.8074 - val_loss: 0.8256 - val_accuracy: 0.6000
# Epoch 8/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.3328 - accuracy: 0.8701 - val_loss: 0.6742 - val_accuracy: 0.5800
# Epoch 9/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.2823 - accuracy: 0.8981 - val_loss: 0.8942 - val_accuracy: 0.4900
# Epoch 10/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.2581 - accuracy: 0.8903 - val_loss: 1.0551 - val_accuracy: 0.4700
# Epoch 11/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.2331 - accuracy: 0.9115 - val_loss: 1.1957 - val_accuracy: 0.4300
# Epoch 12/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.2156 - accuracy: 0.9149 - val_loss: 0.6522 - val_accuracy: 0.6900
# Epoch 13/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.2113 - accuracy: 0.9138 - val_loss: 0.6181 - val_accuracy: 0.7600
# Epoch 14/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.1695 - accuracy: 0.9418 - val_loss: 0.8500 - val_accuracy: 0.5500
# Epoch 15/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.1363 - accuracy: 0.9608 - val_loss: 0.6753 - val_accuracy: 0.7000
# Epoch 16/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.1208 - accuracy: 0.9642 - val_loss: 1.0109 - val_accuracy: 0.5900
# Epoch 17/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.1203 - accuracy: 0.9698 - val_loss: 0.7891 - val_accuracy: 0.6500
# Epoch 18/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.0965 - accuracy: 0.9720 - val_loss: 0.8807 - val_accuracy: 0.6500
# Epoch 19/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.0816 - accuracy: 0.9765 - val_loss: 1.2194 - val_accuracy: 0.6100
# Epoch 20/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.0719 - accuracy: 0.9776 - val_loss: 0.8662 - val_accuracy: 0.7300
# Epoch 21/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.0408 - accuracy: 0.9966 - val_loss: 1.1377 - val_accuracy: 0.5900
# Epoch 22/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.0276 - accuracy: 0.9989 - val_loss: 0.9626 - val_accuracy: 0.6500
# Epoch 23/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.0239 - accuracy: 0.9966 - val_loss: 1.1821 - val_accuracy: 0.6300
# Epoch 23: early stopping
# 11/11 [==============================] - 1s 53ms/step
# Epoch 1/30
# 14/14 [==============================] - 7s 351ms/step - loss: 3.1152 - accuracy: 0.5879 - val_loss: 12.1111 - val_accuracy: 0.3600
# Epoch 2/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.8723 - accuracy: 0.6674 - val_loss: 2.3209 - val_accuracy: 0.6000
# Epoch 3/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.7150 - accuracy: 0.7133 - val_loss: 1.7890 - val_accuracy: 0.5800
# Epoch 4/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.6909 - accuracy: 0.7536 - val_loss: 1.3907 - val_accuracy: 0.6200
# Epoch 5/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.4967 - accuracy: 0.7928 - val_loss: 4.5988 - val_accuracy: 0.3600
# Epoch 6/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.5351 - accuracy: 0.7884 - val_loss: 1.3482 - val_accuracy: 0.6500
# Epoch 7/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.3747 - accuracy: 0.8219 - val_loss: 0.6344 - val_accuracy: 0.7700
# Epoch 8/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.3454 - accuracy: 0.8488 - val_loss: 0.9200 - val_accuracy: 0.6100
# Epoch 9/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.3340 - accuracy: 0.8466 - val_loss: 0.6647 - val_accuracy: 0.7400
# Epoch 10/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.3781 - accuracy: 0.8488 - val_loss: 0.5633 - val_accuracy: 0.7600
# Epoch 11/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.3388 - accuracy: 0.8443 - val_loss: 1.3791 - val_accuracy: 0.4600
# Epoch 12/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.2547 - accuracy: 0.8880 - val_loss: 0.9189 - val_accuracy: 0.5800
# Epoch 13/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.3192 - accuracy: 0.8690 - val_loss: 1.2773 - val_accuracy: 0.5300
# Epoch 14/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.2425 - accuracy: 0.8947 - val_loss: 0.8338 - val_accuracy: 0.6100
# Epoch 15/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.1701 - accuracy: 0.9306 - val_loss: 0.6730 - val_accuracy: 0.6700
# Epoch 16/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.1464 - accuracy: 0.9440 - val_loss: 1.1634 - val_accuracy: 0.5700
# Epoch 17/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.1491 - accuracy: 0.9451 - val_loss: 1.0569 - val_accuracy: 0.5700
# Epoch 18/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.1409 - accuracy: 0.9418 - val_loss: 0.7074 - val_accuracy: 0.7100
# Epoch 19/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.0897 - accuracy: 0.9731 - val_loss: 0.7813 - val_accuracy: 0.7100
# Epoch 20/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.0858 - accuracy: 0.9742 - val_loss: 0.8700 - val_accuracy: 0.6800
# Epoch 20: early stopping
# 11/11 [==============================] - 1s 52ms/step
# Epoch 1/30
# 14/14 [==============================] - 7s 348ms/step - loss: 1.9279 - accuracy: 0.5879 - val_loss: 20.4016 - val_accuracy: 0.3200
# Epoch 2/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.5957 - accuracy: 0.6954 - val_loss: 2.8179 - val_accuracy: 0.4800
# Epoch 3/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.4761 - accuracy: 0.7716 - val_loss: 1.1428 - val_accuracy: 0.6800
# Epoch 4/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.4354 - accuracy: 0.7996 - val_loss: 0.8248 - val_accuracy: 0.6700
# Epoch 5/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.4114 - accuracy: 0.8253 - val_loss: 0.8467 - val_accuracy: 0.6100
# Epoch 6/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.3870 - accuracy: 0.8309 - val_loss: 0.6917 - val_accuracy: 0.7300
# Epoch 7/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.4219 - accuracy: 0.8018 - val_loss: 0.6247 - val_accuracy: 0.7100
# Epoch 8/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.3997 - accuracy: 0.8421 - val_loss: 0.6978 - val_accuracy: 0.5800
# Epoch 9/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.3444 - accuracy: 0.8511 - val_loss: 0.7318 - val_accuracy: 0.6700
# Epoch 10/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.3531 - accuracy: 0.8432 - val_loss: 0.5958 - val_accuracy: 0.7100
# Epoch 11/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.2456 - accuracy: 0.9115 - val_loss: 0.9607 - val_accuracy: 0.5900
# Epoch 12/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.2350 - accuracy: 0.9037 - val_loss: 0.6191 - val_accuracy: 0.6600
# Epoch 13/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.2548 - accuracy: 0.9003 - val_loss: 0.6619 - val_accuracy: 0.6900
# Epoch 14/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.1759 - accuracy: 0.9429 - val_loss: 0.5151 - val_accuracy: 0.7200
# Epoch 15/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.2220 - accuracy: 0.9104 - val_loss: 0.6789 - val_accuracy: 0.6700
# Epoch 16/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.2515 - accuracy: 0.8947 - val_loss: 0.7609 - val_accuracy: 0.6200
# Epoch 17/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.1523 - accuracy: 0.9507 - val_loss: 0.7987 - val_accuracy: 0.6700
# Epoch 18/30
# 14/14 [==============================] - 5s 330ms/step - loss: 0.1215 - accuracy: 0.9563 - val_loss: 0.8907 - val_accuracy: 0.6400
# Epoch 19/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.0937 - accuracy: 0.9698 - val_loss: 1.2811 - val_accuracy: 0.5700
# Epoch 20/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.0776 - accuracy: 0.9742 - val_loss: 0.8802 - val_accuracy: 0.6200
# Epoch 21/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.0748 - accuracy: 0.9709 - val_loss: 1.0464 - val_accuracy: 0.5900
# Epoch 22/30
# 14/14 [==============================] - 5s 332ms/step - loss: 0.0499 - accuracy: 0.9922 - val_loss: 0.5897 - val_accuracy: 0.7700
# Epoch 23/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.0388 - accuracy: 0.9922 - val_loss: 0.8067 - val_accuracy: 0.6900
# Epoch 24/30
# 14/14 [==============================] - 5s 331ms/step - loss: 0.0209 - accuracy: 0.9989 - val_loss: 0.9782 - val_accuracy: 0.6600
# Epoch 24: early stopping
# 11/11 [==============================] - 1s 53ms/step

# %%
print(np.mean(accs), np.std(accs))
plt.plot(accs)

# %%
# To save any output you need.

output_el_path = '/path/to/your/direcotry'
import os
pickle_el_filename = 'performances_of_galaxy_nonegalaxy.pickle'
pickle_el_filepath = os.path.join(output_el_path, pickle_el_filename)

with open(pickle_el_filepath, 'wb') as pickle_file:
    pickle.dump(accs, pickle_file)
